# %%
import pandas as pd


df = pd.read_csv("general_data")


df["idx"] = range(3950, 3950 + len(df))

print(df.head())


df.to_csv("general.csv", index=False, encoding="utf-8-sig")
# Out:
#     idx class                                       conversation
# 0  3950    일반  오늘 날씨 진짜 좋다. 그치? 하늘도 맑고. 응, 어디 놀러 가고 싶어지네. 주말에...
# 1  3951    일반  점심 뭐 먹을래? 글쎄... 어제 치킨 먹어서 오늘은 좀 담백한 거. 그럼 파스타 ...
# 2  3952    일반  요즘 뭐 재미있는 드라마 있어? 아, 나 새로 시작한 거 있는데 완전 내 스타일이야...
# 3  3953    일반  주말에 뭐 했어? 친구 만나서 영화 봤어. 너는? 나는 집에서 뒹굴뒹굴. ㅋㅋ 그게...
# 4  3954    일반  퇴근하고 뭐 해? 바로 집에 가지. 피곤해서... 그치, 나도. 집에 가서 저녁 먹...

# %%
df1 = pd.read_csv("1_clean_reindexed.csv")
df2 = pd.read_csv("2_clean_reindexed.csv")
df3 = pd.read_csv("3_clean_reindexed.csv")
df4 = pd.read_csv("4_clean_reindexed.csv")


merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True)


merged_df["idx"] = range(len(merged_df))


merged_df.to_csv("general_data", index=False, encoding="utf-8-sig")

# %%
file_path = "4_clean_reindexed.csv"


df = pd.read_csv(file_path)


df = df.rename(columns={"label": "class"})
df["class"] = "일반"

output_path = "cleaned_general_data.csv"
df.to_csv(output_path, index=False, encoding="utf-8-sig")
