# %%
import pandas as pd
import numpy as np

# %%
train_path = "train.csv"
train_df = pd.read_csv(train_path)

# %%
threat_df = train_df[train_df['class'] == '협박 대화']
extortion_df = train_df[train_df['class'] == '갈취 대화']
workplace_df = train_df[train_df['class'] == '직장 내 괴롭힘 대화']
other_df = train_df[train_df['class'] == '기타 괴롭힘 대화']
